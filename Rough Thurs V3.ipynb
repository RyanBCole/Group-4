# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

import os

# %%
circuits = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\circuits.csv')
constructor_results = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructor_results.csv')
constructor_standings = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructor_standings.csv')
constructors = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructors.csv')
driver_standings = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\driver_standings.csv')
drivers = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\drivers.csv')
pit_stops = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\pit_stops.csv')
qualifying = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\qualifying.csv')
races = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\races.csv')
seasons = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\seasons.csv')
sprint_results = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\sprint_results.csv')
status = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\status.csv')
results = pd.read_csv(r'C:\Users\redye\Desktop\Group4\Group-4\Formula_1_csvs\results.csv\results.csv')

# %%
driver_standings
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33897              71841    1098       840     0.0        16           16
# 33898              71842    1098       852     0.0        17           17
# 33899              71843    1098       830     0.0        18           18
# 33900              71844    1098       856     0.0        19           19
# 33901              71845    1098       855     0.0        20           20
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 33897     0
# 33898     0
# 33899     0
# 33900     0
# 33901     0
#
# [33902 rows x 7 columns]

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 25835           16             16     0.0    57           \N           \N
# 25836           17             17     0.0    57           \N           \N
# 25837           18             18     0.0    55           \N           \N
# 25838           19             19     0.0    55           \N           \N
# 25839            R             20     0.0    27           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 25835         39   12       1:29.833         211.632        11
# 25836         40   20       1:31.158         208.556        11
# 25837         42   11       1:29.788         211.738         9
# 25838         45   14       1:30.309         210.517       130
# 25839         24   17       1:30.579         209.889        47
#
# [25840 rows x 18 columns]

# %%
circuits = circuits.rename(columns={'name':'circuitName','location':'circuitLocation','country':'circuitCountry','url':'circuitUrl'})
drivers = drivers.rename(columns={'nationality':'driverNationality','url':'driverUrl'})
drivers['driverName'] = drivers['forename']+' '+drivers['surname']
constructors = constructors.rename(columns={'name':'constructorName','nationality':'constructorNationality','url':'constructorUrl'})
pit_stops = pit_stops.rename(columns={'time':'pitTime'})

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# 1         41    3       1:27.739         217.586         1
# 2         41    5       1:28.090         216.719         1
# 3         58    7       1:28.603         215.464         1
# 4         43    1       1:27.418         218.385         1

# %%
df = results.loc[results["raceId"].between(1052,1073)].copy()
df2 = pit_stops.loc[pit_stops["raceId"].between(1052, 1073)].copy()

# %%
df.replace(to_replace = '\\N', value = 'NaN', inplace = True)
df2.replace(to_replace = '\\N', value = 'NaN', inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 420 entries, 24960 to 25399
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   resultId         420 non-null    int64
#  1   raceId           420 non-null    int64
#  2   driverId         420 non-null    int64
#  3   constructorId    420 non-null    int64
#  4   number           420 non-null    object
#  5   grid             420 non-null    int64
#  6   position         420 non-null    object
#  7   positionText     420 non-null    object
#  8   positionOrder    420 non-null    int64
#  9   points           420 non-null    float64
#  10  laps             420 non-null    int64
#  11  time             420 non-null    object
#  12  milliseconds     420 non-null    object
#  13  fastestLap       420 non-null    object
#  14  rank             420 non-null    object
#  15  fastestLapTime   420 non-null    object
#  16  fastestLapSpeed  420 non-null    object
#  17  statusId         420 non-null    int64
# dtypes: float64(1), int64(8), object(9)
# memory usage: 62.3+ KB

# %%
df2.head()
# Out:
#       raceId  driverId  stop  lap   pitTime duration  milliseconds
# 8030    1052       815     1    2  18:11:56   23.993         23993
# 8031    1052       842     1    4  18:16:14   38.338         38338
# 8032    1052         4     1   11  18:27:32   24.373         24373
# 8033    1052       846     1   12  18:29:05   24.899         24899
# 8034    1052       844     1   12  18:29:06   24.925         24925

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 768 entries, 8030 to 8827
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   raceId        768 non-null    int64
#  1   driverId      768 non-null    int64
#  2   stop          768 non-null    int64
#  3   lap           768 non-null    int64
#  4   pitTime       768 non-null    object
#  5   duration      768 non-null    object
#  6   milliseconds  768 non-null    int64
# dtypes: int64(5), object(2)
# memory usage: 48.0+ KB

# %%
df3 = pd.merge(df, df2, on=["raceId", "driverId"],how="left")
df3
# Out:
#      resultId  raceId  driverId  constructorId number  grid position  \
# 0       24966    1052         1            131     44     2        1
# 1       24966    1052         1            131     44     2        1
# 2       24967    1052       830              9     33     1        2
# 3       24967    1052       830              9     33     1        2
# 4       24968    1052       822            131     77     3        3
# ..        ...     ...       ...            ...    ...   ...      ...
# 806     25401    1073       849              3      6    16      NaN
# 807     25402    1073       841             51     99    14      NaN
# 808     25403    1073       847              3     63    17      NaN
# 809     25404    1073         8             51      7    18      NaN
# 810     25405    1073       853            210      9    20      NaN
#
#     positionText  positionOrder  points  ...  fastestLap rank fastestLapTime  \
# 0              1              1    25.0  ...          44    4       1:34.015
# 1              1              1    25.0  ...          44    4       1:34.015
# 2              2              2    18.0  ...          41    2       1:33.228
# 3              2              2    18.0  ...          41    2       1:33.228
# 4              3              3    16.0  ...          56    1       1:32.090
# ..           ...            ...     ...  ...         ...  ...            ...
# 806            R             16     0.0  ...          30   15       1:29.293
# 807            R             17     0.0  ...          33   16       1:29.442
# 808            R             18     0.0  ...          23   19       1:30.647
# 809            R             19     0.0  ...          23   18       1:29.698
# 810            W             20     0.0  ...         NaN    0            NaN
#
#     fastestLapSpeed statusId stop   lap   pitTime  duration  milliseconds_y
# 0           207.235        1  1.0  13.0  18:30:29    24.839         24839.0
# 1           207.235        1  2.0  28.0  18:54:40    24.076         24076.0
# 2           208.984        1  1.0  17.0  18:36:54    24.767         24767.0
# 3           208.984        1  2.0  39.0  19:12:13    23.848         23848.0
# 4           211.566        1  1.0  16.0  18:35:24    24.262         24262.0
# ..              ...      ...  ...   ...       ...       ...             ...
# 806         212.912        3  1.0  28.0  17:46:18    21.241         21241.0
# 807         212.557        6  1.0  17.0  17:29:20    22.283         22283.0
# 808         209.732        6  NaN   NaN       NaN       NaN             NaN
# 809         211.951       23  1.0  21.0  17:35:29    22.338         22338.0
# 810             NaN      139  NaN   NaN       NaN       NaN             NaN
#
# [811 rows x 23 columns]

# %%
df3 = df3.rename(columns={"driverId_x": "driverId"})

# %%
df3 = pd.merge(df3, drivers, on="driverId",how="left")
df3
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         24966    1052         1            131       44     2        1
# 1         24966    1052         1            131       44     2        1
# 2         24966    1052         1            131       44     2        1
# 3         24966    1052         1            131       44     2        1
# 4         24966    1052         1            131       44     2        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 15375     25405    1073       853            210        9    20      NaN
# 15376     25405    1073       853            210        9    20      NaN
# 15377     25405    1073       853            210        9    20      NaN
# 15378     25405    1073       853            210        9    20      NaN
# 15379     25405    1073       853            210        9    20      NaN
#
#       positionText  positionOrder  points  ...  milliseconds_y driverRef  \
# 0                1              1    25.0  ...         23993.0  hamilton
# 1                1              1    25.0  ...         38338.0  hamilton
# 2                1              1    25.0  ...         24373.0  hamilton
# 3                1              1    25.0  ...         24899.0  hamilton
# 4                1              1    25.0  ...         24925.0  hamilton
# ...            ...            ...     ...  ...             ...       ...
# 15375            W             20     0.0  ...         22661.0   mazepin
# 15376            W             20     0.0  ...         21385.0   mazepin
# 15377            W             20     0.0  ...         22070.0   mazepin
# 15378            W             20     0.0  ...         21909.0   mazepin
# 15379            W             20     0.0  ...         21920.0   mazepin
#
#       number_y code forename   surname         dob  driverNationality  \
# 0           44  HAM    Lewis  Hamilton  1985-01-07            British
# 1           44  HAM    Lewis  Hamilton  1985-01-07            British
# 2           44  HAM    Lewis  Hamilton  1985-01-07            British
# 3           44  HAM    Lewis  Hamilton  1985-01-07            British
# 4           44  HAM    Lewis  Hamilton  1985-01-07            British
# ...        ...  ...      ...       ...         ...                ...
# 15375        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15376        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15377        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15378        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15379        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
#
#                                          driverUrl      driverName
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# ...                                            ...             ...
# 15375  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15376  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15377  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15378  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15379  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
#
# [15380 rows x 33 columns]

# %%
df4 = df3.groupby(['code']).mean()['milliseconds_y']
df4
# Out:
# code
# ALO    227302.303385
# BOT    227302.303385
# GAS    227302.303385
# GIO    227302.303385
# HAM    227302.303385
# KUB     22972.196078
# LAT    227302.303385
# LEC    227302.303385
# MAZ    227302.303385
# MSC    227302.303385
# NOR    227302.303385
# OCO    227302.303385
# PER    227302.303385
# RAI    241836.244073
# RIC    227302.303385
# RUS    227302.303385
# SAI    227302.303385
# STR    227302.303385
# TSU    227302.303385
# VER    227302.303385
# VET    227302.303385
# Name: milliseconds_y, dtype: float64

# %%
df3.dtypes
# Out:
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds_x      object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# stop               float64
# lap                float64
# pitTime             object
# duration            object
# milliseconds_y     float64
# dtype: object

# %%
df5 = df3.groupby(['code']).mean()['positionOrder'].reset_index()
df5
# Out:
#    code  positionOrder
# 0   ALO       9.907672
# 1   BOT       6.775033
# 2   GAS       9.087126
# 3   GIO      12.941482
# 4   HAM       3.253576
# 5   KUB      14.568627
# 6   LAT      15.660598
# 7   LEC       7.218466
# 8   MAZ      17.582575
# 9   MSC      16.785436
# 10  NOR       6.934980
# 11  OCO      10.600780
# 12  PER       7.490247
# 13  RAI      12.947075
# 14  RIC       8.968791
# 15  RUS      14.427828
# 16  SAI       6.434330
# 17  STR      12.866060
# 18  TSU      12.663199
# 19  VER       4.763329
# 20  VET      12.583875

# %%
driver_colors = {
    'ALO':'#6CD3BF',
    'BOT':'#1E5BC6',
    'GAS':'#ED1C24',
    'GIO':'#37BEDD',
    'HAM':'#FF80C7',
    'KUB':'#c82e37',
    'LAT':'#FFD800',
    'LEC':'#F58020',
    'MAZ':'#006EFF',
    'MSC':'#FFB800',
    'NOR':'#b2945e',
    'OCO':'#0b361f',
    'PER':'#FFB800',
    'RAI':'#6E0000',
    'RIC':'#6E0000',
    'RUS':'#B6BABD',
    'SAI':'#F596C8',
    'STR':'#2D826D',
    'TSU':'#B12039',
    'VER':'#4E7C9B',
    'VET':'#2293D1'
}

# %%
driver_colors = {
    'ALO': 'red',
    'BOT': 'green'
}

# %%
driver_colors
# Out:
# {'ALO': '#6CD3BF',
#  'BOT': '#1E5BC6',
#  'GAS': '#ED1C24',
#  'GIO': '#37BEDD',
#  'HAM': '#FF80C7',
#  'KUB': '#c82e37',
#  'LAT': '#FFD800',
#  'LEC': '#F58020',
#  'MAZ': '#006EFF',
#  'MSC': '#FFB800',
#  'NOR': '#b2945e',
#  'OCO': '#0b361f',
#  'PER': '#FFB800',
#  'RAI': '#6E0000',
#  'RIC': '#6E0000',
#  'RUS': '#B6BABD',
#  'SAI': '#F596C8',
#  'STR': '#2D826D',
#  'TSU': '#B12039',
#  'VER': '#4E7C9B',
#  'VET': '#2293D1'}

# %%
df5
# Out:
# code
# ALO     9.907672
# BOT     6.775033
# GAS     9.087126
# GIO    12.941482
# HAM     3.253576
# KUB    14.568627
# LAT    15.660598
# LEC     7.218466
# MAZ    17.582575
# MSC    16.785436
# NOR     6.934980
# OCO    10.600780
# PER     7.490247
# RAI    12.947075
# RIC     8.968791
# RUS    14.427828
# SAI     6.434330
# STR    12.866060
# TSU    12.663199
# VER     4.763329
# VET    12.583875
# Name: positionOrder, dtype: float64

# %%
df5['code'].map(driver_colors)
# Out:
# 0       red
# 1     green
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# Name: code, dtype: object

# %%
x = df5
y = df4
plt.scatter(x, y, alpha=0.5)
plt.ylim(25150,25190)
plt.show()

# %%
df3 = df3.rename(columns={"driverId_x": "driverId"})

# %%
df3 = pd.merge(df3, drivers, on="driverId",how="left")
df3
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         24966    1052         1            131       44     2        1
# 1         24966    1052         1            131       44     2        1
# 2         24966    1052         1            131       44     2        1
# 3         24966    1052         1            131       44     2        1
# 4         24966    1052         1            131       44     2        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 15375     25405    1073       853            210        9    20      NaN
# 15376     25405    1073       853            210        9    20      NaN
# 15377     25405    1073       853            210        9    20      NaN
# 15378     25405    1073       853            210        9    20      NaN
# 15379     25405    1073       853            210        9    20      NaN
#
#       positionText  positionOrder  points  ...  milliseconds_y driverRef  \
# 0                1              1    25.0  ...         23993.0  hamilton
# 1                1              1    25.0  ...         38338.0  hamilton
# 2                1              1    25.0  ...         24373.0  hamilton
# 3                1              1    25.0  ...         24899.0  hamilton
# 4                1              1    25.0  ...         24925.0  hamilton
# ...            ...            ...     ...  ...             ...       ...
# 15375            W             20     0.0  ...         22661.0   mazepin
# 15376            W             20     0.0  ...         21385.0   mazepin
# 15377            W             20     0.0  ...         22070.0   mazepin
# 15378            W             20     0.0  ...         21909.0   mazepin
# 15379            W             20     0.0  ...         21920.0   mazepin
#
#       number_y code forename   surname         dob  driverNationality  \
# 0           44  HAM    Lewis  Hamilton  1985-01-07            British
# 1           44  HAM    Lewis  Hamilton  1985-01-07            British
# 2           44  HAM    Lewis  Hamilton  1985-01-07            British
# 3           44  HAM    Lewis  Hamilton  1985-01-07            British
# 4           44  HAM    Lewis  Hamilton  1985-01-07            British
# ...        ...  ...      ...       ...         ...                ...
# 15375        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15376        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15377        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15378        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
# 15379        9  MAZ   Nikita   Mazepin  1999-03-02            Russian
#
#                                          driverUrl      driverName
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# ...                                            ...             ...
# 15375  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15376  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15377  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15378  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
# 15379  http://en.wikipedia.org/wiki/Nikita_Mazepin  Nikita Mazepin
#
# [15380 rows x 33 columns]

# %%
code = df3["code"]
time = df3["points"]

plt.title('Pitstop Time by Driver')
plt.plot(code, time,linewidth=3,)
plt.xlabel('Drivers')
plt.ylabel('milliseconds')
plt.xticks(rotation=45)
plt.show()

# %%
df5 = df3.groupby('code')['points']
df5.count()
# Out:
# code
# ALO    769
# BOT    769
# GAS    769
# GIO    769
# HAM    769
# KUB     51
# LAT    769
# LEC    769
# MAZ    769
# MSC    769
# NOR    769
# OCO    769
# PER    769
# RAI    718
# RIC    769
# RUS    769
# SAI    769
# STR    769
# TSU    769
# VER    769
# VET    769
# Name: points, dtype: int64

# %%
code = df3["code"]
time = df3["points"].count()

plt.title('Pitstop Time by Driver')
plt.plot(code, time,linewidth=3,)
plt.xlabel('Drivers')
plt.ylabel('milliseconds')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15396\3361716578.py in <module>
#       3
#       4 plt.title('Pitstop Time by Driver')
# ----> 5 plt.plot(code, time,linewidth=3,)
#       6 plt.xlabel('Drivers')
#       7 plt.ylabel('milliseconds')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (15380,) and (1,)

# %%
df4 = df3.groupby('code').describe()
df4
# Out:
#      resultId                                                                 \
#         count          mean         std      min      25%      50%       75%
# code
# ALO     769.0  25172.723017  133.707246  24984.0  25042.0  25152.0  25303.00
# BOT     769.0  25169.590377  132.559941  24968.0  25028.0  25148.0  25291.00
# GAS     769.0  25171.902471  133.495219  24982.0  25035.0  25156.0  25305.00
# GIO     769.0  25175.756827  133.970766  24977.0  25040.0  25158.0  25296.00
# HAM     769.0  25166.068921  133.421332  24966.0  25026.0  25146.0  25287.00
# KUB      51.0  25228.196078    9.503725  25220.0  25220.0  25220.0  25239.00
# LAT     769.0  25178.475943  132.919794  24983.0  25041.0  25159.0  25300.00
# LEC     769.0  25170.033810  134.288776  24971.0  25029.0  25147.0  25289.00
# MAZ     769.0  25180.397919  133.980031  24985.0  25044.0  25162.0  25302.00
# MSC     769.0  25179.600780  134.626037  24981.0  25043.0  25163.0  25301.00
# NOR     769.0  25169.750325  135.855478  24969.0  25033.0  25149.0  25293.00
# OCO     769.0  25173.416125  133.287737  24978.0  25034.0  25154.0  25304.00
# PER     769.0  25170.305592  135.367782  24970.0  25030.0  25161.0  25288.00
# RAI     718.0  25172.153203  137.730069  24976.0  25037.0  25160.0  25309.25
# RIC     769.0  25171.784135  135.424795  24972.0  25031.0  25150.0  25290.00
# RUS     769.0  25177.243173  133.697719  24979.0  25039.0  25157.0  25299.00
# SAI     769.0  25169.249675  133.326178  24973.0  25032.0  25151.0  25292.00
# STR     769.0  25175.681404  135.127442  24975.0  25036.0  25153.0  25297.00
# TSU     769.0  25175.478544  134.388846  24974.0  25045.0  25155.0  25294.00
# VER     769.0  25167.578674  133.316194  24967.0  25027.0  25165.0  25286.00
# VET     769.0  25175.399220  134.101749  24980.0  25038.0  25164.0  25295.00
#
#               raceId               ...   lap       milliseconds_y  \
#           max  count         mean  ...   75%   max          count
# code                               ...
# ALO   25393.0  769.0  1062.076723  ...  36.0  70.0          768.0
# BOT   25391.0  769.0  1062.076723  ...  36.0  70.0          768.0
# GAS   25390.0  769.0  1062.076723  ...  36.0  70.0          768.0
# GIO   25402.0  769.0  1062.076723  ...  36.0  70.0          768.0
# HAM   25387.0  769.0  1062.076723  ...  36.0  70.0          768.0
# KUB   25239.0   51.0  1064.431373  ...  33.0  70.0           51.0
# LAT   25401.0  769.0  1062.076723  ...  36.0  70.0          768.0
# LEC   25395.0  769.0  1062.076723  ...  36.0  70.0          768.0
# MAZ   25405.0  769.0  1062.076723  ...  36.0  70.0          768.0
# MSC   25399.0  769.0  1062.076723  ...  36.0  70.0          768.0
# NOR   25392.0  769.0  1062.076723  ...  36.0  70.0          768.0
# OCO   25394.0  769.0  1062.076723  ...  36.0  70.0          768.0
# PER   25400.0  769.0  1062.076723  ...  36.0  70.0          768.0
# RAI   25404.0  718.0  1061.909471  ...  36.0  69.0          717.0
# RIC   25397.0  769.0  1062.076723  ...  36.0  70.0          768.0
# RUS   25403.0  769.0  1062.076723  ...  36.0  70.0          768.0
# SAI   25388.0  769.0  1062.076723  ...  36.0  70.0          768.0
# STR   25398.0  769.0  1062.076723  ...  36.0  70.0          768.0
# TSU   25389.0  769.0  1062.076723  ...  36.0  70.0          768.0
# VER   25386.0  769.0  1062.076723  ...  36.0  70.0          768.0
# VET   25396.0  769.0  1062.076723  ...  36.0  70.0          768.0
#
#                                                                           \
#                mean            std      min       25%      50%       75%
# code
# ALO   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# BOT   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# GAS   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# GIO   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# HAM   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# KUB    22972.196078    4522.180390  18555.0  19263.50  21730.0  24801.50
# LAT   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# LEC   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# MAZ   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# MSC   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# NOR   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# OCO   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# PER   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# RAI   241836.244073  551134.468327  14881.0  21951.00  24176.0  31069.00
# RIC   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# RUS   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# SAI   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# STR   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# TSU   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# VER   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
# VET   227302.303385  535282.154576  14881.0  21813.75  24128.5  30878.75
#
#
#             max
# code
# ALO   2077164.0
# BOT   2077164.0
# GAS   2077164.0
# GIO   2077164.0
# HAM   2077164.0
# KUB     37190.0
# LAT   2077164.0
# LEC   2077164.0
# MAZ   2077164.0
# MSC   2077164.0
# NOR   2077164.0
# OCO   2077164.0
# PER   2077164.0
# RAI   2077164.0
# RIC   2077164.0
# RUS   2077164.0
# SAI   2077164.0
# STR   2077164.0
# TSU   2077164.0
# VER   2077164.0
# VET   2077164.0
#
# [21 rows x 104 columns]

# %% [raw]
# df5.describe()

# %%
s185_line = df4["resultId"]
tumor = df4["raceId"]

plt.title('Capomulin treatmeant of mouse s185')
plt.plot(s185_line, tumor,linewidth=3,)
plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')

plt.show()

# %%
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         24966    1052         1            131       44     2        1
# 1         24966    1052         1            131       44     2        1
# 2         24966    1052         1            131       44     2        1
# 3         24966    1052         1            131       44     2        1
# 4         24966    1052         1            131       44     2        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 14853     25387    1073         1            131       44     2        2
# 14854     25387    1073         1            131       44     2        2
# 14855     25387    1073         1            131       44     2        2
# 14856     25387    1073         1            131       44     2        2
# 14857     25387    1073         1            131       44     2        2
#
#       positionText  positionOrder  points  ...  milliseconds_y driverRef  \
# 0                1              1    25.0  ...         23993.0  hamilton
# 1                1              1    25.0  ...         38338.0  hamilton
# 2                1              1    25.0  ...         24373.0  hamilton
# 3                1              1    25.0  ...         24899.0  hamilton
# 4                1              1    25.0  ...         24925.0  hamilton
# ...            ...            ...     ...  ...             ...       ...
# 14853            2              2    18.0  ...         22661.0  hamilton
# 14854            2              2    18.0  ...         21385.0  hamilton
# 14855            2              2    18.0  ...         22070.0  hamilton
# 14856            2              2    18.0  ...         21909.0  hamilton
# 14857            2              2    18.0  ...         21920.0  hamilton
#
#       number_y code forename   surname         dob  driverNationality  \
# 0           44  HAM    Lewis  Hamilton  1985-01-07            British
# 1           44  HAM    Lewis  Hamilton  1985-01-07            British
# 2           44  HAM    Lewis  Hamilton  1985-01-07            British
# 3           44  HAM    Lewis  Hamilton  1985-01-07            British
# 4           44  HAM    Lewis  Hamilton  1985-01-07            British
# ...        ...  ...      ...       ...         ...                ...
# 14853       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14854       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14855       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14856       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14857       44  HAM    Lewis  Hamilton  1985-01-07            British
#
#                                          driverUrl      driverName
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# ...                                            ...             ...
# 14853  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14854  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14855  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14856  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14857  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
#
# [769 rows x 33 columns]

# %%
HAM = df3[(df3['code'] == 'HAM')]
ALO = df3[(df3['code'] == 'ALO')]
BOT = df3[(df3['code'] == 'BOT')]
GAS = df3[(df3['code'] == 'GAS')]
GIO = df3[(df3['code'] == 'GIO')]
KUB = df3[(df3['code'] == 'KUB')]
LAT = df3[(df3['code'] == 'LAT')]
LEC = df3[(df3['code'] == 'LEC')]
MAZ = df3[(df3['code'] == 'MAZ')]
MSC = df3[(df3['code'] == 'MSC')]
NOR = df3[(df3['code'] == 'NOR')]
OCO = df3[(df3['code'] == 'OCO')]
PER = df3[(df3['code'] == 'PER')]
RAI = df3[(df3['code'] == 'RAI')]
RIC = df3[(df3['code'] == 'RIC')]
RUS = df3[(df3['code'] == 'RUS')]
SAI = df3[(df3['code'] == 'SAI')]
STR = df3[(df3['code'] == 'STR')]
TSU = df3[(df3['code'] == 'TSU')]
VER = df3[(df3['code'] == 'VER')]
VET = df3[(df3['code'] == 'VET')]
HAM
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         24966    1052         1            131       44     2        1
# 1         24966    1052         1            131       44     2        1
# 2         24966    1052         1            131       44     2        1
# 3         24966    1052         1            131       44     2        1
# 4         24966    1052         1            131       44     2        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 14853     25387    1073         1            131       44     2        2
# 14854     25387    1073         1            131       44     2        2
# 14855     25387    1073         1            131       44     2        2
# 14856     25387    1073         1            131       44     2        2
# 14857     25387    1073         1            131       44     2        2
#
#       positionText  positionOrder  points  ...  milliseconds_y driverRef  \
# 0                1              1    25.0  ...         23993.0  hamilton
# 1                1              1    25.0  ...         38338.0  hamilton
# 2                1              1    25.0  ...         24373.0  hamilton
# 3                1              1    25.0  ...         24899.0  hamilton
# 4                1              1    25.0  ...         24925.0  hamilton
# ...            ...            ...     ...  ...             ...       ...
# 14853            2              2    18.0  ...         22661.0  hamilton
# 14854            2              2    18.0  ...         21385.0  hamilton
# 14855            2              2    18.0  ...         22070.0  hamilton
# 14856            2              2    18.0  ...         21909.0  hamilton
# 14857            2              2    18.0  ...         21920.0  hamilton
#
#       number_y code forename   surname         dob  driverNationality  \
# 0           44  HAM    Lewis  Hamilton  1985-01-07            British
# 1           44  HAM    Lewis  Hamilton  1985-01-07            British
# 2           44  HAM    Lewis  Hamilton  1985-01-07            British
# 3           44  HAM    Lewis  Hamilton  1985-01-07            British
# 4           44  HAM    Lewis  Hamilton  1985-01-07            British
# ...        ...  ...      ...       ...         ...                ...
# 14853       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14854       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14855       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14856       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14857       44  HAM    Lewis  Hamilton  1985-01-07            British
#
#                                          driverUrl      driverName
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# ...                                            ...             ...
# 14853  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14854  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14855  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14856  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14857  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
#
# [769 rows x 33 columns]

# %%
HAM = HAM['milliseconds_y']
HAM
# Out:
# 0        23993.0
# 1        38338.0
# 2        24373.0
# 3        24899.0
# 4        24925.0
#           ...
# 14853    22661.0
# 14854    21385.0
# 14855    22070.0
# 14856    21909.0
# 14857    21920.0
# Name: milliseconds_y, Length: 769, dtype: float64

# %%
ALO = ALO['milliseconds_y']
BOT = BOT['milliseconds_y']
GAS = GAS['milliseconds_y']
GIO = GIO['milliseconds_y']
KUB = KUB['milliseconds_y']
LAT = LAT['milliseconds_y']
LEC = LEC['milliseconds_y']
MAZ = MAZ['milliseconds_y']
MSC = MSC['milliseconds_y']
NOR = NOR['milliseconds_y']
OCO = OCO['milliseconds_y']
PER = PER['milliseconds_y']
RAI = RAI['milliseconds_y']
RIC = RIC['milliseconds_y']
RUS = RUS['milliseconds_y']
SAI = SAI['milliseconds_y']
STR = STR['milliseconds_y']
TSU = TSU['milliseconds_y']
VER = VER['milliseconds_y']
VET = VET['milliseconds_y']

# %%
plot = [HAM, ALO, BOT, GAS, GIO, KUB, LAT, LEC, MAZ, MSC, NOR, OCO, PER, RAI, RIC, RUS, SAI, STR, TSU, VER, VET]
drivers = ["HAM", "ALO", "BOT", "GAS", "GIO", "KUB", "LAT", "LEC", "MAZ", "MSC", "NOR", "OCO", "PER", "RAI", "RIC", "RUS", "SAI", "STR", "TSU", "VER", "VET"]

fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.set_title('Driver Pit Times',fontsize =20)
ax1.set_ylabel('Milliseconds',fontsize = 15)
ax1.set_xlabel('Drivers',fontsize = 15)
ax1.boxplot(plot, 0, labels=drivers, widths = 0.4, patch_artist=True,vert=True)
ax1.set_ylim(21500,22500)

plt.show()

# %%
plot = [HAM['milliseconds_y'].count()]
Regimen = ["HAM"]
fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.set_title('Driver Pit Times',fontsize =20)
ax1.set_ylabel('Milliseconds',fontsize = 15)
ax1.set_xlabel('Drivers',fontsize = 15)
ax1.boxplot(plot, 0, labels=Regimen, widths = 0.4, patch_artist=True,vert=True)


plt.show()

# %%
# Out:
#        resultId  raceId  driverId  constructorId number_x  grid position  \
# 0         24966    1052         1            131       44     2        1
# 1         24966    1052         1            131       44     2        1
# 2         24966    1052         1            131       44     2        1
# 3         24966    1052         1            131       44     2        1
# 4         24966    1052         1            131       44     2        1
# ...         ...     ...       ...            ...      ...   ...      ...
# 14853     25387    1073         1            131       44     2        2
# 14854     25387    1073         1            131       44     2        2
# 14855     25387    1073         1            131       44     2        2
# 14856     25387    1073         1            131       44     2        2
# 14857     25387    1073         1            131       44     2        2
#
#       positionText  positionOrder  points  ...  milliseconds_y driverRef  \
# 0                1              1    25.0  ...         23993.0  hamilton
# 1                1              1    25.0  ...         38338.0  hamilton
# 2                1              1    25.0  ...         24373.0  hamilton
# 3                1              1    25.0  ...         24899.0  hamilton
# 4                1              1    25.0  ...         24925.0  hamilton
# ...            ...            ...     ...  ...             ...       ...
# 14853            2              2    18.0  ...         22661.0  hamilton
# 14854            2              2    18.0  ...         21385.0  hamilton
# 14855            2              2    18.0  ...         22070.0  hamilton
# 14856            2              2    18.0  ...         21909.0  hamilton
# 14857            2              2    18.0  ...         21920.0  hamilton
#
#       number_y code forename   surname         dob  driverNationality  \
# 0           44  HAM    Lewis  Hamilton  1985-01-07            British
# 1           44  HAM    Lewis  Hamilton  1985-01-07            British
# 2           44  HAM    Lewis  Hamilton  1985-01-07            British
# 3           44  HAM    Lewis  Hamilton  1985-01-07            British
# 4           44  HAM    Lewis  Hamilton  1985-01-07            British
# ...        ...  ...      ...       ...         ...                ...
# 14853       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14854       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14855       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14856       44  HAM    Lewis  Hamilton  1985-01-07            British
# 14857       44  HAM    Lewis  Hamilton  1985-01-07            British
#
#                                          driverUrl      driverName
# 0      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 1      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 2      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 3      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 4      http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# ...                                            ...             ...
# 14853  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14854  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14855  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14856  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
# 14857  http://en.wikipedia.org/wiki/Lewis_Hamilton  Lewis Hamilton
#
# [769 rows x 33 columns]

# %%
# Out:
# resultId               int64
# raceId                 int64
# driverId               int64
# constructorId          int64
# number_x              object
# grid                   int64
# position              object
# positionText          object
# positionOrder          int64
# points               float64
# laps                   int64
# time                  object
# milliseconds_x        object
# fastestLap            object
# rank                  object
# fastestLapTime        object
# fastestLapSpeed       object
# statusId               int64
# driverId_y           float64
# stop                 float64
# lap                  float64
# pitTime               object
# duration              object
# milliseconds_y       float64
# driverRef             object
# number_y              object
# code                  object
# forename              object
# surname               object
# dob                   object
# driverNationality     object
# driverUrl             object
# driverName            object
# dtype: object

# %%
df2_line = df2["driverId"]
pit = df2["milliseconds"]

plt.title('Pit Time by Driver')
plt.plot(df2_line, pit,linewidth=3,)
plt.xlabel('Driver ID')
plt.ylabel('Pit Time')

plt.show()

# %%
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
#     driverNationality                                       driverUrl  \
# 0             British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1              German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2              German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3             Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4             Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..                ...                                             ...
# 852            German    http://en.wikipedia.org/wiki/Mick_Schumacher
# 853           Chinese        http://en.wikipedia.org/wiki/Guanyu_Zhou
# 854             Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries
# 855        Australian      http://en.wikipedia.org/wiki/Oscar_Piastri
# 856          American     http://en.wikipedia.org/wiki/Logan_Sargeant
#
#             driverName
# 0       Lewis Hamilton
# 1        Nick Heidfeld
# 2         Nico Rosberg
# 3      Fernando Alonso
# 4    Heikki Kovalainen
# ..                 ...
# 852    Mick Schumacher
# 853        Guanyu Zhou
# 854      Nyck de Vries
# 855      Oscar Piastri
# 856     Logan Sargeant
#
# [857 rows x 10 columns]

# %%
# Out:
# driverId              int64
# driverRef            object
# number               object
# code                 object
# forename             object
# surname              object
# dob                  object
# driverNationality    object
# driverUrl            object
# driverName           object
# dtype: object

# %%
# Out:
# raceId            int64
# driverId          int64
# stop              int64
# lap               int64
# pit_time         object
# duration         object
# milliseconds      int64
# seconds         float64
# dtype: object

# %% [markdown]
# df5

# %%
df5
# Out:
#       raceId_x  driverId_x  stop  lap  pit_time duration  milliseconds_x  \
# 0          841         153     1    1  17:05:23   26.898           26898
# 1          841          30     1    1  17:05:52   25.021           25021
# 2          841          17     1   11  17:20:48   23.426           23426
# 3          841           4     1   12  17:22:34   23.251           23251
# 4          841          13     1   13  17:24:10   23.842           23842
# ...        ...         ...   ...  ...       ...      ...             ...
# 9629      1096         849     2   38  18:02:50   25.174           25174
# 9630      1096         840     2   40  18:04:44   21.802           21802
# 9631      1096         839     2   41  18:06:09   21.734           21734
# 9632      1096         846     2   42  18:07:36   21.559           21559
# 9633      1096         855     2   44  18:11:10   23.159           23159
#
#       seconds  resultId  raceId_y  ...  positionOrder  points laps       time  \
# 0      26.898       154        25  ...              6     3.0   70    +40.304
# 1      25.021        31        19  ...              9     0.0   56  +1:16.220
# 2      23.426        18        18  ...             18     0.0    0         \N
# 3      23.251         5        18  ...              5     4.0   58    +18.014
# 4      23.842        14        18  ...             14     0.0   25         \N
# ...       ...       ...       ...  ...            ...     ...  ...        ...
# 9629   25.174       850        57  ...             20     0.0   12         \N
# 9630   21.802       841        57  ...             11     0.0   59         \N
# 9631   21.734       840        57  ...             10     0.0   59         \N
# 9632   21.559       847        57  ...             17     0.0   29         \N
# 9633   23.159       856        58  ...              4     5.0   66    +29.853
#
#      milliseconds_y fastestLap  rank  fastestLapTime  fastestLapSpeed statusId
# 0           5550549         22     6        1:17.507          204.879        1
# 1           5554775         55     9        1:36.206          207.417        1
# 2                \N         \N    \N              \N               \N        4
# 3           5708630         43     1        1:27.418          218.385        1
# 4                \N         21    11        1:29.502          213.300        4
# ...             ...        ...   ...             ...              ...      ...
# 9629             \N         11    16        1:35.415          194.233        9
# 9630             \N         57    14        1:34.091          196.966       11
# 9631             \N         47    11        1:34.035          197.084       11
# 9632             \N         21    20        1:37.214          190.639        9
# 9633        5211612         42     1        1:16.648          217.320        1
#
# [9634 rows x 26 columns]

# %%
# Out:
#        resultId  raceId  driverId_x  constructorId number_x  grid position  \
# 0             1      18           1              1       22     1        1
# 1             2      18           2              2        3     5        2
# 2             3      18           3              3        7     7        3
# 3             4      18           4              4        5    11        4
# 4             5      18           5              1       23     3        5
# ...         ...     ...         ...            ...      ...   ...      ...
# 25835     25841    1096         854            210       47    12       16
# 25836     25842    1096         825            210       20    16       17
# 25837     25843    1096           1            131       44     5       18
# 25838     25844    1096         849              3        6    20       19
# 25839     25845    1096           4            214       14    10       \N
#
#       positionText  positionOrder  points  ...  driverId_y   driverRef  \
# 0                1              1    10.0  ...           2    heidfeld
# 1                2              2     8.0  ...           3     rosberg
# 2                3              3     6.0  ...           4      alonso
# 3                4              4     5.0  ...           5  kovalainen
# 4                5              5     4.0  ...           6    nakajima
# ...            ...            ...     ...  ...         ...         ...
# 25835           16             16     0.0  ...         856    de_vries
# 25836           17             17     0.0  ...         826       kvyat
# 25837           18             18     0.0  ...           2    heidfeld
# 25838           19             19     0.0  ...         851      aitken
# 25839            R             20     0.0  ...           5  kovalainen
#
#       number_y code  forename     surname         dob  driverNationality  \
# 0           \N  HEI      Nick    Heidfeld  1977-05-10             German
# 1            6  ROS      Nico     Rosberg  1985-06-27             German
# 2           14  ALO  Fernando      Alonso  1981-07-29            Spanish
# 3           \N  KOV    Heikki  Kovalainen  1981-10-19            Finnish
# 4           \N  NAK    Kazuki    Nakajima  1985-01-11           Japanese
# ...        ...  ...       ...         ...         ...                ...
# 25835       45  DEV      Nyck    de Vries  1995-02-06              Dutch
# 25836       26  KVY    Daniil       Kvyat  1994-04-26            Russian
# 25837       \N  HEI      Nick    Heidfeld  1977-05-10             German
# 25838       89  AIT      Jack      Aitken  1995-09-23            British
# 25839       \N  KOV    Heikki  Kovalainen  1981-10-19            Finnish
#
#                                             driverUrl         driverName
# 0          http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick Heidfeld
# 1           http://en.wikipedia.org/wiki/Nico_Rosberg       Nico Rosberg
# 2        http://en.wikipedia.org/wiki/Fernando_Alonso    Fernando Alonso
# 3      http://en.wikipedia.org/wiki/Heikki_Kovalainen  Heikki Kovalainen
# 4        http://en.wikipedia.org/wiki/Kazuki_Nakajima    Kazuki Nakajima
# ...                                               ...                ...
# 25835      http://en.wikipedia.org/wiki/Nyck_de_Vries      Nyck de Vries
# 25836       http://en.wikipedia.org/wiki/Daniil_Kvyat       Daniil Kvyat
# 25837      http://en.wikipedia.org/wiki/Nick_Heidfeld      Nick Heidfeld
# 25838        http://en.wikipedia.org/wiki/Jack_Aitken        Jack Aitken
# 25839  http://en.wikipedia.org/wiki/Heikki_Kovalainen  Heikki Kovalainen
#
# [25840 rows x 28 columns]

# %%
# Out:
#        resultId  raceId_x  driverId_x  constructorId_x number_x  grid  \
# 0             1        18           1                1       22     1
# 1             2        18           2                2        3     5
# 2             3        18           3                3        7     7
# 3             4        18           4                4        5    11
# 4             5        18           5                1       23     3
# ...         ...       ...         ...              ...      ...   ...
# 25835     25841      1096         854              210       47    12
# 25836     25842      1096         825              210       20    16
# 25837     25843      1096           1              131       44     5
# 25838     25844      1096         849                3        6    20
# 25839     25845      1096           4              214       14    10
#
#       position positionText  positionOrder  points  ...  driverId_y  \
# 0            1            1              1    10.0  ...           2
# 1            2            2              2     8.0  ...           3
# 2            3            3              3     6.0  ...           4
# 3            4            4              4     5.0  ...           5
# 4            5            5              5     4.0  ...           6
# ...        ...          ...            ...     ...  ...         ...
# 25835       16           16             16     0.0  ...         856
# 25836       17           17             17     0.0  ...         826
# 25837       18           18             18     0.0  ...           2
# 25838       19           19             19     0.0  ...         851
# 25839       \N            R             20     0.0  ...           5
#
#         driverRef number_y code  forename     surname         dob  \
# 0        heidfeld       \N  HEI      Nick    Heidfeld  1977-05-10
# 1         rosberg        6  ROS      Nico     Rosberg  1985-06-27
# 2          alonso       14  ALO  Fernando      Alonso  1981-07-29
# 3      kovalainen       \N  KOV    Heikki  Kovalainen  1981-10-19
# 4        nakajima       \N  NAK    Kazuki    Nakajima  1985-01-11
# ...           ...      ...  ...       ...         ...         ...
# 25835    de_vries       45  DEV      Nyck    de Vries  1995-02-06
# 25836       kvyat       26  KVY    Daniil       Kvyat  1994-04-26
# 25837    heidfeld       \N  HEI      Nick    Heidfeld  1977-05-10
# 25838      aitken       89  AIT      Jack      Aitken  1995-09-23
# 25839  kovalainen       \N  KOV    Heikki  Kovalainen  1981-10-19
#
#        driverNationality                                       driverUrl  \
# 0                 German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 1                 German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 2                Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 3                Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# 4               Japanese    http://en.wikipedia.org/wiki/Kazuki_Nakajima
# ...                  ...                                             ...
# 25835              Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries
# 25836            Russian       http://en.wikipedia.org/wiki/Daniil_Kvyat
# 25837             German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 25838            British        http://en.wikipedia.org/wiki/Jack_Aitken
# 25839            Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
#
#               driverName
# 0          Nick Heidfeld
# 1           Nico Rosberg
# 2        Fernando Alonso
# 3      Heikki Kovalainen
# 4        Kazuki Nakajima
# ...                  ...
# 25835      Nyck de Vries
# 25836       Daniil Kvyat
# 25837      Nick Heidfeld
# 25838        Jack Aitken
# 25839  Heikki Kovalainen
#
# [25840 rows x 60 columns]

# %%
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     45  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
#     driverNationality                                       driverUrl  \
# 0             British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1              German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2              German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3             Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4             Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..                ...                                             ...
# 852            German    http://en.wikipedia.org/wiki/Mick_Schumacher
# 853           Chinese        http://en.wikipedia.org/wiki/Guanyu_Zhou
# 854             Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries
# 855        Australian      http://en.wikipedia.org/wiki/Oscar_Piastri
# 856          American     http://en.wikipedia.org/wiki/Logan_Sargeant
#
#             driverName
# 0       Lewis Hamilton
# 1        Nick Heidfeld
# 2         Nico Rosberg
# 3      Fernando Alonso
# 4    Heikki Kovalainen
# ..                 ...
# 852    Mick Schumacher
# 853        Guanyu Zhou
# 854      Nyck de Vries
# 855      Oscar Piastri
# 856     Logan Sargeant
#
# [857 rows x 10 columns]

# %%
# Out:
#       raceId  driverId  stop  lap  pit_time duration  milliseconds  seconds
# 8030    1052       815     1    2  18:11:56   23.993         23993   23.993
# 8031    1052       842     1    4  18:16:14   38.338         38338   38.338
# 8032    1052         4     1   11  18:27:32   24.373         24373   24.373
# 8033    1052       846     1   12  18:29:05   24.899         24899   24.899
# 8034    1052       844     1   12  18:29:06   24.925         24925   24.925
# ...      ...       ...   ...  ...       ...      ...           ...      ...
# 8823    1073       840     2   52  18:22:55   22.661         22661   22.661
# 8824    1073       815     3   53  18:23:09   21.385         21385   21.385
# 8825    1073       854     2   52  18:23:42   22.070         22070   22.070
# 8826    1073       852     2   53  18:24:01   21.909         21909   21.909
# 8827    1073       842     2   54  18:25:56   21.920         21920   21.920
#
# [768 rows x 8 columns]

# %%
x = df3['code']
y = df3['milliseconds_y']


# Set the xlabel and ylabel, title using class methods
plt.title('Driver by ms')
plt.plot(x, y,linewidth=3,)
plt.xlabel('Driver')
plt.ylabel('Milli')
plt.xticks(rotation=45)

plt.show()

# %%
plot = [df3['driverId']]
Regimen= ['milliseconds_y']

fig1, ax1 = plt.subplots(figsize=(15, 10))
ax1.set_title('Average Pit Stop Time',fontsize =20)
ax1.set_ylabel('Milliseconds',fontsize = 15)
ax1.set_xlabel('Drivers',fontsize = 15)
ax1.boxplot(plot, 0, 'gD', widths = 0.4, patch_artist=True,vert=True)
plt.ylim(600, 1000)
plt.show()

# %%
df3['milliseconds_y'].unique
# Out:
# <bound method Series.unique of 0        23993.0
# 1        38338.0
# 2        24373.0
# 3        24899.0
# 4        24925.0
#           ...
# 15375    22661.0
# 15376    21385.0
# 15377    22070.0
# 15378    21909.0
# 15379    21920.0
# Name: milliseconds_y, Length: 15380, dtype: float64>

# %%
df3['milliseconds_y'].isna().sum()
# Out:
# 20

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25852\2283206624.py in <module>
# ----> 1 df3['milliseconds_y'].str.replace('NaN', '')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
#     179         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     229
#     230         if inferred_dtype not in allowed_types:
# --> 231             raise AttributeError("Can only use .str accessor with string values!")
#     232         return inferred_dtype
#     233
#
# AttributeError: Can only use .str accessor with string values!
