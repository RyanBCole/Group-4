# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %%
Results = pd.read_csv("C:/Users/tsswi/OneDrive/Desktop/DU_Classwork/Formula_1_csvs/results.csv/results.csv")
#Qualifying = pd.read_csv("C:/Users/tsswi/OneDrive/Desktop/DU_Classwork/Formula_1_csvs/qualifying.csv")
Pit_stops = pd.read_csv("C:/Users/tsswi/OneDrive/Desktop/DU_Classwork/Formula_1_csvs/pit_stops.csv")
#Race = pd.read_csv("C:/Users/tsswi/OneDrive/Desktop/DU_Classwork/Formula_1_csvs/races.csv")
constructors = pd.read_csv("C:/Users/tsswi/Group-4/Formula_1_csvs/constructors.csv")

# %%
constructors.shape
# Out:
# (211, 3)

# %%
Results.head(10)
# Out:
#    resultId  raceId  driverId  constructorId number  grid position  \
# 0         1      18         1              1     22     1        1
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
# 5         6      18         6              3      8    13        6
# 6         7      18         7              5     14    17        7
# 7         8      18         8              6      1    15        8
# 8         9      18         9              2      4     2       \N
# 9        10      18        10              7     12    18       \N
#
#   positionText  positionOrder  points  laps         time milliseconds  \
# 0            1              1    10.0    58  1:34:50.616      5690616
# 1            2              2     8.0    58       +5.478      5696094
# ...

# %%
Pit_stops.head()
# Out:
#    raceId  driverId  stop  lap      time duration  milliseconds
# 0     841       153     1    1  17:05:23   26.898         26898
# 1     841        30     1    1  17:05:52   25.021         25021
# 2     841        17     1   11  17:20:48   23.426         23426
# 3     841         4     1   12  17:22:34   23.251         23251
# 4     841        13     1   13  17:24:10   23.842         23842

# %%
# Merge the two DFs on 'driverId'
#mouse_data_complete = pd.merge(mouse_metadata, study_results, how="outer", on=["Mouse ID", "Mouse ID"])
raw_df = pd.merge(Results, Pit_stops, on =['driverId'], how = 'outer')
raw_df
# Out:
#          resultId  raceId_x  driverId  constructorId number  grid position  \
# 0               1        18         1              1     22     1        1
# 1               1        18         1              1     22     1        1
# 2               1        18         1              1     22     1        1
# 3               1        18         1              1     22     1        1
# 4               1        18         1              1     22     1        1
# ...           ...       ...       ...            ...    ...   ...      ...
# 1692334     25837      1096       855             51     24    15       12
# 1692335     25837      1096       855             51     24    15       12
# 1692336     25837      1096       855             51     24    15       12
# 1692337     25837      1096       855             51     24    15       12
# 1692338     25714      1089       856              3     45     8        9
#
# ...

# %%
# We don't need all the drivers, so let's filter by ID's 1052:1073
filtered_raw = raw_df[raw_df['raceId_x'] == 1052| 1053| 1054| 1057| 1058| 1059| 1060| 1061|1062|
                      1063|1064|1065|1066|1067|1068|1069|1070|1071|1072|1073]

# %%
filtered_raw
# Out:
#          resultId  raceId_x  driverId  constructorId number  grid position  \
# 141470      25685      1087         1            131     44     4       \N
# 141471      25685      1087         1            131     44     4       \N
# 141472      25685      1087         1            131     44     4       \N
# 141473      25685      1087         1            131     44     4       \N
# 141474      25685      1087         1            131     44     4       \N
# ...           ...       ...       ...            ...    ...   ...      ...
# 1692045     25679      1087       855             51     24    18       14
# 1692046     25679      1087       855             51     24    18       14
# 1692047     25679      1087       855             51     24    18       14
# 1692048     25679      1087       855             51     24    18       14
# 1692049     25679      1087       855             51     24    18       14
#
# ...

# %% [markdown]
# Okay, so I merged the two df's I think we will need to answer question one; results and pit stops. However, the raceId columns are different and do not correlate. Do we know which one is the correct column - I've been using the raceId_x because it seems to match up with the ID's that Talon sent us in the Slack chat.

# %%
test = filtered_raw[filtered_raw['raceId_x'] == 1087]
test
# Out:
#          resultId  raceId_x  driverId  constructorId number  grid position  \
# 141470      25685      1087         1            131     44     4       \N
# 141471      25685      1087         1            131     44     4       \N
# 141472      25685      1087         1            131     44     4       \N
# 141473      25685      1087         1            131     44     4       \N
# 141474      25685      1087         1            131     44     4       \N
# ...           ...       ...       ...            ...    ...   ...      ...
# 1692045     25679      1087       855             51     24    18       14
# 1692046     25679      1087       855             51     24    18       14
# 1692047     25679      1087       855             51     24    18       14
# 1692048     25679      1087       855             51     24    18       14
# 1692049     25679      1087       855             51     24    18       14
#
# ...

# %% [markdown]
# I have a bilivit. I wonder what the boys have done.
