# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

import os

from scipy.stats import linregress
from scipy import stats

# %%
# read in csvs
circuits = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\circuits.csv', na_values=r'\N')
constructor_results = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructor_results.csv', na_values=r'\N')
constructor_standings = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructor_standings.csv', na_values=r'\N')
constructors = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\constructors.csv', na_values=r'\N')
driver_standings = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\driver_standings.csv', na_values=r'\N')
drivers = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\drivers.csv', na_values=r'\N')
pit_stops = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\pit_stops.csv', na_values=r'\N')
qualifying = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\qualifying.csv', na_values=r'\N')
races = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\races.csv', na_values=r'\N')
seasons = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\seasons.csv', na_values=r'\N')
sprint_results = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\sprint_results.csv', na_values=r'\N')
status = pd.read_csv(r'C:\Users\redye\Desktop\Formula 1\status.csv', na_values=r'\N')
results = pd.read_csv(r'C:\Users\redye\Desktop\Group4\Group-4\Formula_1_csvs\results.csv\results.csv', na_values=r'\N')

# %%
driver_standings
# Out:
#        driverStandingsId  raceId  driverId  points  position positionText  \
# 0                      1      18         1    10.0         1            1
# 1                      2      18         2     8.0         2            2
# 2                      3      18         3     6.0         3            3
# 3                      4      18         4     5.0         4            4
# 4                      5      18         5     4.0         5            5
# ...                  ...     ...       ...     ...       ...          ...
# 33897              71841    1098       840     0.0        16           16
# 33898              71842    1098       852     0.0        17           17
# 33899              71843    1098       830     0.0        18           18
# 33900              71844    1098       856     0.0        19           19
# 33901              71845    1098       855     0.0        20           20
#
#        wins
# 0         1
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 33897     0
# 33898     0
# 33899     0
# 33900     0
# 33901     0
#
# [33902 rows x 7 columns]

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 0             1      18         1              1    22.0     1       1.0
# 1             2      18         2              2     3.0     5       2.0
# 2             3      18         3              3     7.0     7       3.0
# 3             4      18         4              4     5.0    11       4.0
# 4             5      18         5              1    23.0     3       5.0
# ...         ...     ...       ...            ...     ...   ...       ...
# 25835     25841    1096       854            210    47.0    12      16.0
# 25836     25842    1096       825            210    20.0    16      17.0
# 25837     25843    1096         1            131    44.0     5      18.0
# 25838     25844    1096       849              3     6.0    20      19.0
# 25839     25845    1096         4            214    14.0    10       NaN
#
#       positionText  positionOrder  points  laps         time  milliseconds  \
# 0                1              1    10.0    58  1:34:50.616     5690616.0
# 1                2              2     8.0    58       +5.478     5696094.0
# 2                3              3     6.0    58       +8.163     5698779.0
# 3                4              4     5.0    58      +17.181     5707797.0
# 4                5              5     4.0    58      +18.014     5708630.0
# ...            ...            ...     ...   ...          ...           ...
# 25835           16             16     0.0    57          NaN           NaN
# 25836           17             17     0.0    57          NaN           NaN
# 25837           18             18     0.0    55          NaN           NaN
# 25838           19             19     0.0    55          NaN           NaN
# 25839            R             20     0.0    27          NaN           NaN
#
#        fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 0            39.0   2.0       1:27.452          218.300         1
# 1            41.0   3.0       1:27.739          217.586         1
# 2            41.0   5.0       1:28.090          216.719         1
# 3            58.0   7.0       1:28.603          215.464         1
# 4            43.0   1.0       1:27.418          218.385         1
# ...           ...   ...            ...              ...       ...
# 25835        39.0  12.0       1:29.833          211.632        11
# 25836        40.0  20.0       1:31.158          208.556        11
# 25837        42.0  11.0       1:29.788          211.738         9
# 25838        45.0  14.0       1:30.309          210.517       130
# 25839        24.0  17.0       1:30.579          209.889        47
#
# [25840 rows x 18 columns]

# %%
# Rename columns for later merging 
drivers = drivers.rename(columns={'nationality':'driverNationality','url':'driverUrl'})
drivers['driverName'] = drivers['forename']+' '+drivers['surname']
constructors = constructors.rename(columns={'name':'constructorName','nationality':'constructorNationality','url':'constructorUrl'})
pit_stops = pit_stops.rename(columns={'time':'pitTime'})

# %%
results.head()
# Out:
#    resultId  raceId  driverId  constructorId  number  grid  position  \
# 0         1      18         1              1    22.0     1       1.0
# 1         2      18         2              2     3.0     5       2.0
# 2         3      18         3              3     7.0     7       3.0
# 3         4      18         4              4     5.0    11       4.0
# 4         5      18         5              1    23.0     3       5.0
#
#   positionText  positionOrder  points  laps         time  milliseconds  \
# 0            1              1    10.0    58  1:34:50.616     5690616.0
# 1            2              2     8.0    58       +5.478     5696094.0
# 2            3              3     6.0    58       +8.163     5698779.0
# 3            4              4     5.0    58      +17.181     5707797.0
# 4            5              5     4.0    58      +18.014     5708630.0
#
#    fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 0        39.0   2.0       1:27.452          218.300         1
# 1        41.0   3.0       1:27.739          217.586         1
# 2        41.0   5.0       1:28.090          216.719         1
# 3        58.0   7.0       1:28.603          215.464         1
# 4        43.0   1.0       1:27.418          218.385         1

# %%
# locate the races and pit stops we need 
df = results.loc[results["raceId"].between(1052,1073)].copy()
df2 = pit_stops.loc[pit_stops["raceId"].between(1052, 1073)].copy()

# %%
# this df is from Results and contains only the races we need 
df.head()
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 24960     24966    1052         1            131    44.0     2       1.0
# 24961     24967    1052       830              9    33.0     1       2.0
# 24962     24968    1052       822            131    77.0     3       3.0
# 24963     24969    1052       846              1     4.0     7       4.0
# 24964     24970    1052       815              9    11.0     0       5.0
#
#       positionText  positionOrder  points  laps         time  milliseconds  \
# 24960            1              1    25.0    56  1:32:03.897     5523897.0
# 24961            2              2    18.0    56       +0.745     5524642.0
# 24962            3              3    16.0    56      +37.383     5561280.0
# 24963            4              4    12.0    56      +46.466     5570363.0
# 24964            5              5    10.0    56      +52.047     5575944.0
#
#        fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 24960        44.0   4.0       1:34.015          207.235         1
# 24961        41.0   2.0       1:33.228          208.984         1
# 24962        56.0   1.0       1:32.090          211.566         1
# 24963        38.0   6.0       1:34.396          206.398         1
# 24964        44.0   3.0       1:33.970          207.334         1

# %%
# change dtype for milliseconds
df.astype({"milliseconds": "float"})
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 24960     24966    1052         1            131    44.0     2       1.0
# 24961     24967    1052       830              9    33.0     1       2.0
# 24962     24968    1052       822            131    77.0     3       3.0
# 24963     24969    1052       846              1     4.0     7       4.0
# 24964     24970    1052       815              9    11.0     0       5.0
# ...         ...     ...       ...            ...     ...   ...       ...
# 25395     25401    1073       849              3     6.0    16       NaN
# 25396     25402    1073       841             51    99.0    14       NaN
# 25397     25403    1073       847              3    63.0    17       NaN
# 25398     25404    1073         8             51     7.0    18       NaN
# 25399     25405    1073       853            210     9.0    20       NaN
#
#       positionText  positionOrder  points  laps         time  milliseconds  \
# 24960            1              1    25.0    56  1:32:03.897     5523897.0
# 24961            2              2    18.0    56       +0.745     5524642.0
# 24962            3              3    16.0    56      +37.383     5561280.0
# 24963            4              4    12.0    56      +46.466     5570363.0
# 24964            5              5    10.0    56      +52.047     5575944.0
# ...            ...            ...     ...   ...          ...           ...
# 25395            R             16     0.0    50          NaN           NaN
# 25396            R             17     0.0    33          NaN           NaN
# 25397            R             18     0.0    26          NaN           NaN
# 25398            R             19     0.0    25          NaN           NaN
# 25399            W             20     0.0     0          NaN           NaN
#
#        fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 24960        44.0   4.0       1:34.015          207.235         1
# 24961        41.0   2.0       1:33.228          208.984         1
# 24962        56.0   1.0       1:32.090          211.566         1
# 24963        38.0   6.0       1:34.396          206.398         1
# 24964        44.0   3.0       1:33.970          207.334         1
# ...           ...   ...            ...              ...       ...
# 25395        30.0  15.0       1:29.293          212.912         3
# 25396        33.0  16.0       1:29.442          212.557         6
# 25397        23.0  19.0       1:30.647          209.732         6
# 25398        23.0  18.0       1:29.698          211.951        23
# 25399         NaN   0.0            NaN              NaN       139
#
# [420 rows x 18 columns]

# %%
# This df is from pit stops and contains only the pit stop info relavant to the races we're analyzing 
df2.head()
# Out:
#       raceId  driverId  stop  lap   pitTime duration  milliseconds
# 8030    1052       815     1    2  18:11:56   23.993         23993
# 8031    1052       842     1    4  18:16:14   38.338         38338
# 8032    1052         4     1   11  18:27:32   24.373         24373
# 8033    1052       846     1   12  18:29:05   24.899         24899
# 8034    1052       844     1   12  18:29:06   24.925         24925

# %%
df2.dtypes
# Out:
# raceId           int64
# driverId         int64
# stop             int64
# lap              int64
# pitTime         object
# duration        object
# milliseconds     int64
# dtype: object

# %%
# change dtype for milliseconds
df.astype({"milliseconds": "float"})
# Out:
#        resultId  raceId  driverId  constructorId  number  grid  position  \
# 24960     24966    1052         1            131    44.0     2       1.0
# 24961     24967    1052       830              9    33.0     1       2.0
# 24962     24968    1052       822            131    77.0     3       3.0
# 24963     24969    1052       846              1     4.0     7       4.0
# 24964     24970    1052       815              9    11.0     0       5.0
# ...         ...     ...       ...            ...     ...   ...       ...
# 25395     25401    1073       849              3     6.0    16       NaN
# 25396     25402    1073       841             51    99.0    14       NaN
# 25397     25403    1073       847              3    63.0    17       NaN
# 25398     25404    1073         8             51     7.0    18       NaN
# 25399     25405    1073       853            210     9.0    20       NaN
#
#       positionText  positionOrder  points  laps         time  milliseconds  \
# 24960            1              1    25.0    56  1:32:03.897     5523897.0
# 24961            2              2    18.0    56       +0.745     5524642.0
# 24962            3              3    16.0    56      +37.383     5561280.0
# 24963            4              4    12.0    56      +46.466     5570363.0
# 24964            5              5    10.0    56      +52.047     5575944.0
# ...            ...            ...     ...   ...          ...           ...
# 25395            R             16     0.0    50          NaN           NaN
# 25396            R             17     0.0    33          NaN           NaN
# 25397            R             18     0.0    26          NaN           NaN
# 25398            R             19     0.0    25          NaN           NaN
# 25399            W             20     0.0     0          NaN           NaN
#
#        fastestLap  rank fastestLapTime  fastestLapSpeed  statusId
# 24960        44.0   4.0       1:34.015          207.235         1
# 24961        41.0   2.0       1:33.228          208.984         1
# 24962        56.0   1.0       1:32.090          211.566         1
# 24963        38.0   6.0       1:34.396          206.398         1
# 24964        44.0   3.0       1:33.970          207.334         1
# ...           ...   ...            ...              ...       ...
# 25395        30.0  15.0       1:29.293          212.912         3
# 25396        33.0  16.0       1:29.442          212.557         6
# 25397        23.0  19.0       1:30.647          209.732         6
# 25398        23.0  18.0       1:29.698          211.951        23
# 25399         NaN   0.0            NaN              NaN       139
#
# [420 rows x 18 columns]

# %%
# Merge the filtered results and pit stops onto one df
df3 = pd.merge(df, df2, on=["raceId", "driverId"],how="right")
df3
# Out:
#      resultId  raceId  driverId  constructorId  number  grid  position  \
# 0       24970    1052       815              9    11.0     0       5.0
# 1       24982    1052       842            213    10.0     5      17.0
# 2       24984    1052         4            214    14.0     9       NaN
# 3       24969    1052       846              1     4.0     7       4.0
# 4       24971    1052       844              6    16.0     4       6.0
# ..        ...     ...       ...            ...     ...   ...       ...
# 763     25398    1073       840            117    18.0    13      13.0
# 764     25400    1073       815              9    11.0     4      15.0
# 765     25399    1073       854            210    47.0    19      14.0
# 766     25389    1073       852            213    22.0     8       4.0
# 767     25390    1073       842            213    10.0    12       5.0
#
#     positionText  positionOrder  points  ...  fastestLap  rank  \
# 0              5              5    10.0  ...        44.0   3.0
# 1             17             17     0.0  ...        48.0   5.0
# 2              R             19     0.0  ...        31.0  17.0
# 3              4              4    12.0  ...        38.0   6.0
# 4              6              6     8.0  ...        39.0  11.0
# ..           ...            ...     ...  ...         ...   ...
# 763           13             13     0.0  ...        48.0  13.0
# 764           15             15     0.0  ...        51.0   2.0
# 765           14             14     0.0  ...        42.0  17.0
# 766            4              4    12.0  ...        50.0   7.0
# 767            5              5    10.0  ...        49.0   6.0
#
#      fastestLapTime  fastestLapSpeed  statusId stop  lap   pitTime  duration  \
# 0          1:33.970          207.334         1    1    2  18:11:56    23.993
# 1          1:34.090          207.069        31    1    4  18:16:14    38.338
# 2          1:36.063          202.816        23    1   11  18:27:32    24.373
# 3          1:34.396          206.398         1    1   12  18:29:05    24.899
# 4          1:34.988          205.112         1    1   12  18:29:06    24.925
# ..              ...              ...       ...  ...  ...       ...       ...
# 763        1:28.567          214.657        11    2   52  18:22:55    22.661
# 764        1:26.419          219.993         5    3   53  18:23:09    21.385
# 765        1:29.457          212.522        11    2   52  18:23:42    22.070
# 766        1:27.496          217.285         1    2   53  18:24:01    21.909
# 767        1:27.342          217.668         1    2   54  18:25:56    21.920
#
#      milliseconds_y
# 0             23993
# 1             38338
# 2             24373
# 3             24899
# 4             24925
# ..              ...
# 763           22661
# 764           21385
# 765           22070
# 766           21909
# 767           21920
#
# [768 rows x 23 columns]

# %%
# rename the column 
df3 = df3.rename(columns={"driverId_x": "driverId"})

# %%
# Merge this df with the drivers csv
df3 = pd.merge(df3, drivers, on=["driverId"] ,how="left")
df3
# Out:
#      resultId  raceId  driverId  constructorId  number_x  grid  position  \
# 0       24970    1052       815              9      11.0     0       5.0
# 1       24982    1052       842            213      10.0     5      17.0
# 2       24984    1052         4            214      14.0     9       NaN
# 3       24969    1052       846              1       4.0     7       4.0
# 4       24971    1052       844              6      16.0     4       6.0
# ..        ...     ...       ...            ...       ...   ...       ...
# 763     25398    1073       840            117      18.0    13      13.0
# 764     25400    1073       815              9      11.0     4      15.0
# 765     25399    1073       854            210      47.0    19      14.0
# 766     25389    1073       852            213      22.0     8       4.0
# 767     25390    1073       842            213      10.0    12       5.0
#
#     positionText  positionOrder  points  ...  milliseconds_y        driverRef  \
# 0              5              5    10.0  ...           23993            perez
# 1             17             17     0.0  ...           38338            gasly
# 2              R             19     0.0  ...           24373           alonso
# 3              4              4    12.0  ...           24899           norris
# 4              6              6     8.0  ...           24925          leclerc
# ..           ...            ...     ...  ...             ...              ...
# 763           13             13     0.0  ...           22661           stroll
# 764           15             15     0.0  ...           21385            perez
# 765           14             14     0.0  ...           22070  mick_schumacher
# 766            4              4    12.0  ...           21909          tsunoda
# 767            5              5    10.0  ...           21920            gasly
#
#      number_y  code  forename     surname         dob  driverNationality  \
# 0        11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 1        10.0   GAS    Pierre       Gasly  1996-02-07             French
# 2        14.0   ALO  Fernando      Alonso  1981-07-29            Spanish
# 3         4.0   NOR     Lando      Norris  1999-11-13            British
# 4        16.0   LEC   Charles     Leclerc  1997-10-16         Monegasque
# ..        ...   ...       ...         ...         ...                ...
# 763      18.0   STR     Lance      Stroll  1998-10-29           Canadian
# 764      11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 765      47.0   MSC      Mick  Schumacher  1999-03-22             German
# 766      22.0   TSU      Yuki     Tsunoda  2000-05-11           Japanese
# 767      10.0   GAS    Pierre       Gasly  1996-02-07             French
#
#                                           driverUrl       driverName
# 0    http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez     Sergio Pérez
# 1         http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre Gasly
# 2      http://en.wikipedia.org/wiki/Fernando_Alonso  Fernando Alonso
# 3         http://en.wikipedia.org/wiki/Lando_Norris     Lando Norris
# 4      http://en.wikipedia.org/wiki/Charles_Leclerc  Charles Leclerc
# ..                                              ...              ...
# 763       http://en.wikipedia.org/wiki/Lance_Stroll     Lance Stroll
# 764  http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez     Sergio Pérez
# 765    http://en.wikipedia.org/wiki/Mick_Schumacher  Mick Schumacher
# 766       http://en.wikipedia.org/wiki/Yuki_Tsunoda     Yuki Tsunoda
# 767       http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre Gasly
#
# [768 rows x 32 columns]

# %%
df3 = df3.loc[df3['milliseconds_y'] <= 90000]
df3
# Out:
#      resultId  raceId  driverId  constructorId  number_x  grid  position  \
# 0       24970    1052       815              9      11.0     0       5.0
# 1       24982    1052       842            213      10.0     5      17.0
# 2       24984    1052         4            214      14.0     9       NaN
# 3       24969    1052       846              1       4.0     7       4.0
# 4       24971    1052       844              6      16.0     4       6.0
# ..        ...     ...       ...            ...       ...   ...       ...
# 763     25398    1073       840            117      18.0    13      13.0
# 764     25400    1073       815              9      11.0     4      15.0
# 765     25399    1073       854            210      47.0    19      14.0
# 766     25389    1073       852            213      22.0     8       4.0
# 767     25390    1073       842            213      10.0    12       5.0
#
#     positionText  positionOrder  points  ...  milliseconds_y        driverRef  \
# 0              5              5    10.0  ...           23993            perez
# 1             17             17     0.0  ...           38338            gasly
# 2              R             19     0.0  ...           24373           alonso
# 3              4              4    12.0  ...           24899           norris
# 4              6              6     8.0  ...           24925          leclerc
# ..           ...            ...     ...  ...             ...              ...
# 763           13             13     0.0  ...           22661           stroll
# 764           15             15     0.0  ...           21385            perez
# 765           14             14     0.0  ...           22070  mick_schumacher
# 766            4              4    12.0  ...           21909          tsunoda
# 767            5              5    10.0  ...           21920            gasly
#
#      number_y  code  forename     surname         dob  driverNationality  \
# 0        11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 1        10.0   GAS    Pierre       Gasly  1996-02-07             French
# 2        14.0   ALO  Fernando      Alonso  1981-07-29            Spanish
# 3         4.0   NOR     Lando      Norris  1999-11-13            British
# 4        16.0   LEC   Charles     Leclerc  1997-10-16         Monegasque
# ..        ...   ...       ...         ...         ...                ...
# 763      18.0   STR     Lance      Stroll  1998-10-29           Canadian
# 764      11.0   PER    Sergio       Pérez  1990-01-26            Mexican
# 765      47.0   MSC      Mick  Schumacher  1999-03-22             German
# 766      22.0   TSU      Yuki     Tsunoda  2000-05-11           Japanese
# 767      10.0   GAS    Pierre       Gasly  1996-02-07             French
#
#                                           driverUrl       driverName
# 0    http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez     Sergio Pérez
# 1         http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre Gasly
# 2      http://en.wikipedia.org/wiki/Fernando_Alonso  Fernando Alonso
# 3         http://en.wikipedia.org/wiki/Lando_Norris     Lando Norris
# 4      http://en.wikipedia.org/wiki/Charles_Leclerc  Charles Leclerc
# ..                                              ...              ...
# 763       http://en.wikipedia.org/wiki/Lance_Stroll     Lance Stroll
# 764  http://en.wikipedia.org/wiki/Sergio_P%C3%A9rez     Sergio Pérez
# 765    http://en.wikipedia.org/wiki/Mick_Schumacher  Mick Schumacher
# 766       http://en.wikipedia.org/wiki/Yuki_Tsunoda     Yuki Tsunoda
# 767       http://en.wikipedia.org/wiki/Pierre_Gasly     Pierre Gasly
#
# [665 rows x 32 columns]

# %%
wetdf = df3.loc[(df3["raceId"] == 1053) | (df3["raceId"] == 1062)]
wetdf
# Out:
#      resultId  raceId  driverId  constructorId  number_x  grid  position  \
# 40      24994    1053       839            214      31.0     9       9.0
# 41      25000    1053        20            117       5.0     0      15.0
# 42      25001    1053       854            210      47.0    18      16.0
# 43      25002    1053       853            210       9.0    19      17.0
# 44      24992    1053       842            213      10.0     5       7.0
# ..        ...     ...       ...            ...       ...   ...       ...
# 432     25169    1062         4            214      14.0     9       4.0
# 433     25174    1062       830              9      33.0     3       9.0
# 434     25167    1062         1            131      44.0     1       2.0
# 435     25175    1062         8             51       7.0    13      10.0
# 436     25170    1062       842            213      10.0     5       5.0
#
#     positionText  positionOrder  points  ...  milliseconds_y        driverRef  \
# 40             9              9     2.0  ...           30866             ocon
# 41            15             15     0.0  ...           32024           vettel
# 42            16             16     0.0  ...           51007  mick_schumacher
# 43            17             17     0.0  ...           31168          mazepin
# 44             7              7     6.0  ...           31068            gasly
# ..           ...            ...     ...  ...             ...              ...
# 432            4              4    12.0  ...           21523           alonso
# 433            9              9     2.0  ...           20848   max_verstappen
# 434            2              2    18.0  ...           21208         hamilton
# 435           10             10     1.0  ...           21172        raikkonen
# 436            5              5    11.0  ...           21543            gasly
#
#      number_y  code   forename     surname         dob  driverNationality  \
# 40       31.0   OCO    Esteban        Ocon  1996-09-17             French
# 41        5.0   VET  Sebastian      Vettel  1987-07-03             German
# 42       47.0   MSC       Mick  Schumacher  1999-03-22             German
# 43        9.0   MAZ     Nikita     Mazepin  1999-03-02            Russian
# 44       10.0   GAS     Pierre       Gasly  1996-02-07             French
# ..        ...   ...        ...         ...         ...                ...
# 432      14.0   ALO   Fernando      Alonso  1981-07-29            Spanish
# 433      33.0   VER        Max  Verstappen  1997-09-30              Dutch
# 434      44.0   HAM      Lewis    Hamilton  1985-01-07            British
# 435       7.0   RAI       Kimi   Räikkönen  1979-10-17            Finnish
# 436      10.0   GAS     Pierre       Gasly  1996-02-07             French
#
#                                              driverUrl        driverName
# 40           http://en.wikipedia.org/wiki/Esteban_Ocon      Esteban Ocon
# 41       http://en.wikipedia.org/wiki/Sebastian_Vettel  Sebastian Vettel
# 42        http://en.wikipedia.org/wiki/Mick_Schumacher   Mick Schumacher
# 43         http://en.wikipedia.org/wiki/Nikita_Mazepin    Nikita Mazepin
# 44           http://en.wikipedia.org/wiki/Pierre_Gasly      Pierre Gasly
# ..                                                 ...               ...
# 432       http://en.wikipedia.org/wiki/Fernando_Alonso   Fernando Alonso
# 433        http://en.wikipedia.org/wiki/Max_Verstappen    Max Verstappen
# 434        http://en.wikipedia.org/wiki/Lewis_Hamilton    Lewis Hamilton
# 435  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...    Kimi Räikkönen
# 436          http://en.wikipedia.org/wiki/Pierre_Gasly      Pierre Gasly
#
# [76 rows x 32 columns]

# %%
wetdf['stop'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 40     1
# 41     1
# 42     1
# 43     1
# 44     1
#       ..
# 432    3
# 433    5
# 434    4
# 435    4
# 436    4
# Name: stop, Length: 76, dtype: int64>

# %%
wetorder = wetdf.groupby(['code'])['positionOrder'].mean()
wetorder
# Out:
# code
# ALO     7.000000
# BOT    18.000000
# GAS     6.000000
# GIO    13.428571
# HAM     2.000000
# LAT     7.000000
# LEC     4.000000
# MAZ    16.250000
# MSC    14.400000
# NOR     9.000000
# OCO     6.333333
# PER    11.000000
# RAI    11.200000
# RIC     9.333333
# RUS    11.666667
# SAI     3.666667
# STR     8.000000
# TSU     9.000000
# VER     7.400000
# VET    16.666667
# Name: positionOrder, dtype: float64

# %%
wetpit = wetdf.groupby(['code'])['milliseconds_y'].mean()
wetpit
# Out:
# code
# ALO    36777.500000
# BOT    30167.000000
# GAS    33684.166667
# GIO    33821.428571
# HAM    33439.166667
# LAT    30892.500000
# LEC    31002.000000
# MAZ    34028.000000
# MSC    38726.800000
# NOR    34460.500000
# OCO    35019.333333
# PER    44608.000000
# RAI    37250.400000
# RIC    30151.666667
# RUS    27181.000000
# SAI    31864.333333
# STR    48264.000000
# TSU    39133.750000
# VER    25903.600000
# VET    36389.666667
# Name: milliseconds_y, dtype: float64

# %%
x = wetorder
y = wetpit

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x, y)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x,y)
regress_values = x * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 100.58x + 33675.99

# %%
# Print line equation
print(line_eq)

# Print the r value
print(f"The r-value is: {rvalue**2}")

# Print line equation
print(line_eq)

# Print the r value
print(f"The r-value is: {rvalue**2}")

plt.show()
plt.scatter(x, y)
plt.plot(x, regress_values, "r")
plt.annotate(line_eq, (10,5000), fontsize=15, color='r')
plt.title('Mean Pit Stop Time and Finishing Position in Weather')
plt.xlabel("Finishing Position")
plt.ylabel('Mean Pit Stop Time (s)')

plt.show()
# Out:
# y = 100.58x + 33675.99
# The r-value is: 0.007043395845241737
# y = 100.58x + 33675.99
# The r-value is: 0.007043395845241737

# %%
wetdf['pitcounts'] = 1
wetdf
# Out:
# C:\Users\redye\AppData\Local\Temp\ipykernel_40836\508931637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wetdf['pitcounts'] = 1
#      resultId  raceId  driverId  constructorId  number_x  grid  position  \
# 40      24994    1053       839            214      31.0     9       9.0
# 41      25000    1053        20            117       5.0     0      15.0
# 42      25001    1053       854            210      47.0    18      16.0
# 43      25002    1053       853            210       9.0    19      17.0
# 44      24992    1053       842            213      10.0     5       7.0
# ..        ...     ...       ...            ...       ...   ...       ...
# 432     25169    1062         4            214      14.0     9       4.0
# 433     25174    1062       830              9      33.0     3       9.0
# 434     25167    1062         1            131      44.0     1       2.0
# 435     25175    1062         8             51       7.0    13      10.0
# 436     25170    1062       842            213      10.0     5       5.0
#
#     positionText  positionOrder  points  ...        driverRef number_y  code  \
# 40             9              9     2.0  ...             ocon     31.0   OCO
# 41            15             15     0.0  ...           vettel      5.0   VET
# 42            16             16     0.0  ...  mick_schumacher     47.0   MSC
# 43            17             17     0.0  ...          mazepin      9.0   MAZ
# 44             7              7     6.0  ...            gasly     10.0   GAS
# ..           ...            ...     ...  ...              ...      ...   ...
# 432            4              4    12.0  ...           alonso     14.0   ALO
# 433            9              9     2.0  ...   max_verstappen     33.0   VER
# 434            2              2    18.0  ...         hamilton     44.0   HAM
# 435           10             10     1.0  ...        raikkonen      7.0   RAI
# 436            5              5    11.0  ...            gasly     10.0   GAS
#
#       forename     surname         dob  driverNationality  \
# 40     Esteban        Ocon  1996-09-17             French
# 41   Sebastian      Vettel  1987-07-03             German
# 42        Mick  Schumacher  1999-03-22             German
# 43      Nikita     Mazepin  1999-03-02            Russian
# 44      Pierre       Gasly  1996-02-07             French
# ..         ...         ...         ...                ...
# 432   Fernando      Alonso  1981-07-29            Spanish
# 433        Max  Verstappen  1997-09-30              Dutch
# 434      Lewis    Hamilton  1985-01-07            British
# 435       Kimi   Räikkönen  1979-10-17            Finnish
# 436     Pierre       Gasly  1996-02-07             French
#
#                                              driverUrl        driverName  \
# 40           http://en.wikipedia.org/wiki/Esteban_Ocon      Esteban Ocon
# 41       http://en.wikipedia.org/wiki/Sebastian_Vettel  Sebastian Vettel
# 42        http://en.wikipedia.org/wiki/Mick_Schumacher   Mick Schumacher
# 43         http://en.wikipedia.org/wiki/Nikita_Mazepin    Nikita Mazepin
# 44           http://en.wikipedia.org/wiki/Pierre_Gasly      Pierre Gasly
# ..                                                 ...               ...
# 432       http://en.wikipedia.org/wiki/Fernando_Alonso   Fernando Alonso
# 433        http://en.wikipedia.org/wiki/Max_Verstappen    Max Verstappen
# 434        http://en.wikipedia.org/wiki/Lewis_Hamilton    Lewis Hamilton
# 435  http://en.wikipedia.org/wiki/Kimi_R%C3%A4ikk%C...    Kimi Räikkönen
# 436          http://en.wikipedia.org/wiki/Pierre_Gasly      Pierre Gasly
#
#      pitcounts
# 40           1
# 41           1
# 42           1
# 43           1
# 44           1
# ..         ...
# 432          1
# 433          1
# 434          1
# 435          1
# 436          1
#
# [76 rows x 33 columns]

# %%
wetstops = wetdf.groupby(['code'])['pitcounts'].sum()/2
wetstops
# Out:
# code
# ALO    2.0
# BOT    0.5
# GAS    3.0
# GIO    3.5
# HAM    3.0
# LAT    1.0
# LEC    0.5
# MAZ    2.0
# MSC    2.5
# NOR    1.0
# OCO    3.0
# PER    0.5
# RAI    2.5
# RIC    1.5
# RUS    1.5
# SAI    1.5
# STR    1.0
# TSU    2.0
# VER    2.5
# VET    3.0
# Name: pitcounts, dtype: float64

# %%
x2 = wetorder
y2 = wetstops

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x2, y2)
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x2, y2)
regress_values = x2 * slope + intercept
line_eq = 'y = ' + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
# Out:
# y = 0.0x + 1.88

# %%
# Print line equation
print(line_eq)

# Print the r value
print(f"The r-value is: {rvalue**2}")

# Print line equation
print(line_eq)

# Print the r value
print(f"The r-value is: {rvalue**2}")

plt.show()
plt.scatter(x2, y2)
plt.plot(x2, regress_values, "r")
plt.annotate(line_eq, (10,5000), fontsize=15, color='r')
plt.title('Pitstops by Position in Weather')
plt.xlabel("Finishing Position")
plt.ylabel('Average Number of Pit Stops')

plt.show()
# Out:
# y = 0.0x + 1.88
# The r-value is: 0.00013526409084388307
# y = 0.0x + 1.88
# The r-value is: 0.00013526409084388307
